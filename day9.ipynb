# %% [markdown]
# <a href="https://colab.research.google.com/github/armnkumar321-spec/pythonclasses/blob/main/day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#oops
class mirai_class:
  strength=100
  teacher=['A','B','C']
  div=['alpha','beta']
  sub=['ds','dev','dsa']

  def __init__():
    print("hello")

obj=mirai_class()
print(obj.strength)
# Out:
# 100

# %%
class students:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def display(self):
    print('Name:',self.name)
    print('Age:',self.age)
a=students('aman',20)
a.display()
# Out:
# Name: aman
# Age: 20

# %% [markdown]
# #homewrok->distructor ke bare mai padna hai
# #inheritence study all type
# #virtual polymorphism

# %%
def student(name,age):
  print(name,age)
student('aman',20)
# Out:
# aman 20
