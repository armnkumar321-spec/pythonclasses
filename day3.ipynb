# %% [markdown]
# <a href="https://colab.research.google.com/github/armnkumar321-spec/pythonclasses/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_twonumber(a,b):
  c=a+b
  return c
print(add_twonumber(2,3))
# Out:
# 5

# %%
#function
def add_twonumber(a, b):
  c = a + b
  return c


result = add_twonumber(2, 3)
print(result)
# Out:
# 5

# %%
#lambda function
x=lambda a,b:b*a
print(x(2,3))
# Out:
# 6

# %%
#string
st=""
print(len(st))
st="aman kumar"
st1=st.upper()
print(st1)
st2=st1.lower()
print(st2)
st3=st2.title()
print(st3)
st4=st3.capitalize()
print(st4)
# Out:
# 0
# AMAN KUMAR
# aman kumar
# Aman Kumar
# Aman kumar

# %%
f_name=' aman'
l_name=' kumar'
#strip-> remove spaces form front and back
print(f_name+l_name)
f_name=f_name.strip()
l_name=l_name.strip()
print(f_name+l_name)
#lstrip->remove space from left
#rstrip->remove space from right
# Out:
#  aman kumar
# amankumar

# %%
a=" today"
b=" weather"
c="is Good"
a=a.strip()
b=b.strip()


d=a.capitalize()
X=d+','+b+' '+c+'. '
print(X)


c=c.replace('Good','bad')
Y=d+','+b+' '+c+'. '
print(Y)
Z=X.find('Good')
print(Z)
P=Y.startswith('')
print(P)
# Out:
# Today,weather is Good.
# Today,weather is bad.
# 17
# False

# %%
#indexing
s="hello world"
print(s[1::3])
# Out:
# eood

# %%
#set
st={2,2,23,2,1}
print(st)
# Out:
# {1, 2, 23}

# %% [markdown]
# #homework ->explore all set's function;

# %%
#dictionary
dct ={
    "name": ["Aman","akshita"],
    "age":"20",
    "occupation":"student",
    "class":"b-tech",
    "Roll no":9

}
print(dct['name'][0])
dct["id"]=12
print(dct)
del dct["name"]
print(dct)
# Out:
# Aman
# {'name': ['Aman', 'akshita'], 'age': '20', 'occupation': 'student', 'class': 'b-tech', 'Roll no': 9, 'id': 12}
# {'age': '20', 'occupation': 'student', 'class': 'b-tech', 'Roll no': 9, 'id': 12}
